# %%
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
nltk.download('stopwords')
from CleanData import clean_comment, get_bag_of_words
import datetime
# Out:
# [nltk_data] Downloading package stopwords to /home/zchao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## We can find 50 ID's in the list MediaTwitterID which also appeared in the MediaBiasChart. From the MediaBiasChart we have a scaled left/right ideology score.

# %%
tweets_df = pd.read_csv('news_filtered.csv')

mediaList = [['thinkprogress', -20], ['MSNBC', -20],['thenation',-17],['thedailybeast',-16],['CNN',-15],
       ['MotherJones',-15],['cnsnews',26],['foxnewsradio',24],['FDRLST',23],['BreitbartNews',20],
       ['DailyCaller',20],['theblaze',16],['FoxNews',15],['BBC',-2],['businessinsider',-1],['CBSNews',-2],
       ['TheEconomist',-3], ['thehill',0],['WSJ',2],['ABC',-1],['AP',-1],['TheAtlantic',-7],['axios',-6],
       ['BBC',-3],['BuzzFeed',-8],['DailySignal',25],['newrepublic',-12],['ForeignPolicy',-2],['TheIJR',7],
       ['NRO',15],['NPR',-3],['nypost',4],['nytimes',-4],['NewYorker',-8],['newsmax',13],['Newsweek',-3],
       ['OANN',14],['politico',-5],['qz',-4],['reason',3],['Reuters',-1],['Slate',-19],['TPM',-6],
       ['VanityFair',-18],['voxdotcom',-10],['dcexaminer',12],['FreeBeacon',18],['washingtonpost',-4],
       ['WashTimes',13],['TheWeek',-9]]

media_df = pd.DataFrame(mediaList, columns =['MediaTwitterAcc', 'LeftRightCoordinate'])
k = 15
all_media = media_df['MediaTwitterAcc'].tolist()
left_media = media_df.loc[media_df['LeftRightCoordinate']<=-k]
left_media = left_media['MediaTwitterAcc'].tolist()
right_media = media_df.loc[media_df['LeftRightCoordinate']>=k]
right_media = right_media['MediaTwitterAcc'].tolist()
neutral_media = media_df.loc[(media_df['LeftRightCoordinate']>=-6) \
                                & (media_df['LeftRightCoordinate']<=6)]
neutral_media = neutral_media['MediaTwitterAcc'].tolist()
len(left_media), len(right_media), len(neutral_media)
# Out:
# (8, 10, 21)

# %% [markdown]
# ## Number of Tweets: Daily plot and Monthly plot

# %%
# 357363 Tweets in total
#  32200 from 2016.1.1 to 2016.12.31
# 138590 from 2017.1.1 to 2017.12.31
# 186573 from 2018.1.1 to 2018.12.31

tweets_df['created_at'] = pd.to_datetime(tweets_df['created_at'])
tweets_df.groupby(tweets_df['created_at'].dt.date).size().plot()

# %%
tweets_df.groupby([tweets_df['created_at'].dt.year, tweets_df['created_at'].dt.month]).size().plot()

# %% [markdown]
# ## Now take a look into their topics (from the list of bag_of_words, try find some words which is really a topic)

# %%
import preprocessor as p
tweets_df['clean_tweet']  = tweets_df['clean_tweet'].apply(p.clean)
bag_of_words, vectorizer = get_bag_of_words(tweets_df['clean_tweet'],ngram_range=(1,3), min_df=0.0005)
print(vectorizer.get_feature_names())

# %%
data = np.zeros([media_df.shape[0], bag_of_words.shape[1]])
for index, row in media_df.iterrows():
    BoW = bag_of_words[tweets_df['user_name'] == row['MediaTwitterAcc'],:]
    data[index] = sum(BoW)
labels = media_df['LeftRightCoordinate'].to_numpy()

# %%
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=1)

reg = LinearRegression().fit(X_train, y_train)
y_pred = reg.predict(X_test)
print('Mean squared error: %.2f'% mean_squared_error(y_test, y_pred))
# Out:
# Mean squared error: 221.29

# %%
reg.coef_
# Out:
# array([ 0.01702575, -0.00353617,  0.00586989, ...,  0.00454989,
#         0.00101636, -0.00812849])

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fd2951b82103> in <module>
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined

# %%
tweets_df['created_at'].head(10)
# Out:
# 0    Sat Nov 26 11:00:10 +0000 2016
# 1    Sat Nov 26 10:11:27 +0000 2016
# 2    Sat Nov 26 15:08:55 +0000 2016
# 3    Sat Nov 26 07:52:34 +0000 2016
# 4    Sat Nov 26 15:43:39 +0000 2016
# 5    Sat Nov 26 05:15:06 +0000 2016
# 6    Sat Nov 26 05:55:04 +0000 2016
# 7    Sat Nov 26 07:15:03 +0000 2016
# 8    Sat Nov 26 04:59:05 +0000 2016
# 9    Sat Nov 26 12:16:47 +0000 2016
# Name: created_at, dtype: object

# %%
a = tweets_df.head(1)

# %%
a = a.loc[(pd.to_datetime(a['created_at']).dt.date > start_time) & \
           (pd.to_datetime(a['created_at']).dt.date < end_time)]

# %%
# Out:
#   user_name                  id  \
# 0       ABC  802466973086908417
#
#                                          clean_tweet  \
# 0  Fidel Castro Dead at 90: Barbara Walters talks...
#
#                        created_at
# 0  Sat Nov 26 11:00:10 +0000 2016

# %%
# Out:
# ['000', '000 people', '10', '100', '11', '13', '130', '130 000', '15', '18', '20', '200', '30', '300', '50', '500', 'abc', 'ability', 'able', 'abolish', 'abortion', 'abroad', 'absolutely', 'abuse', 'abuse allegations', 'abuses', 'academy', 'accept', 'access', 'accident', 'accidentally', 'according', 'according new', 'account', 'accounts', 'accusations', 'accused', 'accusers', 'accuses', 'across', 'across country', 'act', 'acting', 'action', 'actions', 'active', 'activist', 'activists', 'activity', 'actor', 'actress', 'acts', 'actual', 'actually', 'ad', 'adam', 'adam schiff', 'add', 'added', 'addiction', 'adding', 'additional', 'address', 'addresses', 'adds', 'admin', 'administration', 'admits', 'admitted', 'ads', 'adult', 'adults', 'advance', 'advantage', 'advice', 'adviser', 'advisers', 'advocates', 'affair', 'affairs', 'affect', 'affected', 'affordable', 'afghan', 'afghanistan', 'africa', 'african', 'african american', 'ag', 'age', 'agencies', 'agency', 'agenda', 'agent', 'agent attack', 'agents', 'ago', 'agree', 'agreed', 'agreement', 'agrees', 'ahead', 'ai', 'aid', 'aide', 'aides', 'aim', 'aimed', 'aims', 'air', 'air force', 'aircraft', 'airline', 'airlines', 'airport', 'al', 'al qaeda', 'alabama', 'alan', 'alarm', 'alaska', 'alcohol', 'alec', 'alec baldwin', 'aleppo', 'alert', 'alive', 'allegations', 'alleged', 'allegedly', 'alleging', 'alliance', 'allies', 'allow', 'allowed', 'allowing', 'allows', 'ally', 'almost', 'alone', 'along', 'already', 'also', 'alt', 'alt right', 'always', 'amazing', 'amazon', 'ambassador', 'amendment', 'america', 'american', 'american history', 'american people', 'americans', 'amid', 'among', 'amount', 'amp', 'amp friends', 'amy', 'analysis', 'analysis trump', 'analyst', 'analytica', 'anchor', 'ancient', 'anderson', 'andrew', 'andrew mccabe', 'angela', 'angela merkel', 'angeles', 'anger', 'angry', 'animal', 'animals', 'anniversary', 'announce', 'announced', 'announcement', 'announces', 'annual', 'another', 'answer', 'answers', 'anthem', 'anthony', 'anthony bourdain', 'anti', 'anti semitic', 'anti trump', 'anxiety', 'anymore', 'anyone', 'anything', 'ap', 'ap photo', 'apart', 'apartment', 'apologize', 'apologizes', 'apology', 'app', 'apparent', 'apparently', 'appeal', 'appeals', 'appeals court', 'appear', 'appearance', 'appeared', 'appears', 'apple', 'appointed', 'approach', 'approval', 'approval rating', 'approve', 'approved', 'approves', 'april', 'arabia', 'archive', 'arctic', 'area', 'areas', 'argues', 'argument', 'arizona', 'armed', 'arms', 'army', 'around', 'around world', 'arrest', 'arrested', 'arrests', 'arrives', 'art', 'article', 'artist', 'asia', 'asian', 'aside', 'ask', 'asked', 'asking', 'asks', 'assad', 'assange', 'assassination', 'assault', 'assistant', 'associate', 'association', 'asylum', 'athletes', 'atlanta', 'atlantic', 'attack', 'attack syria', 'attacked', 'attacker', 'attacking', 'attacks', 'attempt', 'attempted', 'attempts', 'attend', 'attention', 'attorney', 'attorney general', 'attorney michael', 'attorney michael cohen', 'audience', 'audio', 'australia', 'australian', 'author', 'authorities', 'authorities say', 'authority', 'auto', 'average', 'avoid', 'award', 'awards', 'away', 'babies', 'baby', 'back', 'back trump', 'backed', 'background', 'backing', 'backlash', 'backs', 'bad', 'bag', 'baker', 'baldwin', 'ball', 'ballot', 'baltimore', 'ban', 'bank', 'banking', 'banks', 'banned', 'banning', 'bannon', 'bans', 'bar', 'barack', 'barack obama', 'barbara', 'barbara bush', 'baron', 'baron cohen', 'base', 'baseball', 'based', 'basic', 'basically', 'basketball', 'bathroom', 'battle', 'beach', 'bear', 'beat', 'beating', 'beautiful', 'became', 'become', 'becomes', 'becoming', 'beer', 'began', 'begin', 'beginning', 'begins', 'behavior', 'behind', 'beijing', 'believe', 'believed', 'believes', 'bell', 'ben', 'benefit', 'benefits', 'bernardino', 'bernie', 'bernie sanders', 'best', 'bet', 'betsy', 'betsy devos', 'better', 'beyond', 'bias', 'bid', 'biden', 'big', 'bigger', 'biggest', 'bik ...
